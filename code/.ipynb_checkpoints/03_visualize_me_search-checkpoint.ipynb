# %% [markdown]
# # 03 — Visualizations
# Loads the cleaned data from `02_data_clean_visualize_me_search.ipynb` and produces all maps.

# %%
import os
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.colors import ListedColormap
from matplotlib.patches import Patch
from pathlib import Path
from scipy import stats
import numpy as np



# Find the repo root by searching upward for README.md
# This works no matter where Jupyter is launched from
def find_repo_root(start=Path().resolve()):
    for parent in [start] + list(start.parents):
        if (parent / "README.md").exists() and (parent / "data").exists():
            return parent
    raise FileNotFoundError("Could not find repo root — make sure README.md and data/ exist.")

REPO_ROOT = find_repo_root()
os.chdir(REPO_ROOT)

print("Working directory:", os.getcwd())
print("Files in data/:", os.listdir('data'))
# Out:
# Working directory: /Users/charlottewest/Documents/QSS20-CW-Final
# Files in data/: ['cleaned_data', 'final_clean_race.csv', '.DS_Store', 'final_map.csv', '01_pulls', 'raw', 'nj_pfas_map.png']

# %% [markdown]
# ## Load cleaned data

# %%
# Load shapefile and cleaned data, then merge
# Drop the text geometry column from the CSV — the real geometry comes from the GeoJSON
nj_shapes = gpd.read_file('data/01_pulls/nj_zcta_2024.geojson')
final_df  = pd.read_csv('data/cleaned_data/final_map.csv', dtype={'ZIPCODE': str})
final_df  = final_df.drop(columns=[c for c in final_df.columns if 'geometry' in c.lower()])

map_df = nj_shapes.merge(final_df, on='ZIPCODE', how='left')
map_df = map_df.set_geometry('geometry')

print(map_df.columns.tolist())
# Out:
# ['ZIPCODE', 'GEOID20_x', 'GEOIDFQ20_x', 'CLASSFP20_x', 'MTFCC20_x', 'FUNCSTAT20_x', 'ALAND20_x', 'AWATER20_x', 'INTPTLAT20_x', 'INTPTLON20_x', 'geometry', 'GEOID20_y', 'GEOIDFQ20_y', 'CLASSFP20_y', 'MTFCC20_y', 'FUNCSTAT20_y', 'ALAND20_y', 'AWATER20_y', 'INTPTLAT20_y', 'INTPTLON20_y', 'NAME', 'total_pop', 'pct_white', 'pct_black', 'pct_native', 'pct_asian', 'pct_pacific_islander', 'pct_hispanic', 'pct_nonhispanic_white', 'hh_total', 'hh_less_than_10k', 'hh_10k_to_15k', 'hh_15k_to_25k', 'hh_25k_to_35k', 'hh_35k_to_50k', 'hh_50k_to_75k', 'hh_75k_to_100k', 'hh_100k_to_150k', 'hh_150k_to_200k', 'hh_200k_or_more', 'hh_median_income', 'hh_mean_income', 'pct_poc', 'max_pfas', 'mean_pfas', 'total_detections', 'num_contaminants', 'exceeds_mcl_mean', 'exceeds_mcl_max']

# %% [markdown]
# ## Mean PFAS concentration by ZIP (µg/L)

# %% [markdown]
# It should be noted that the MCL for PFAS is 0.004 ppb (which is what all of these graphs are in)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 14))

map_df.plot(
    column       = 'mean_pfas',
    cmap         = 'OrRd',
    linewidth    = 0.5,
    edgecolor    = 'black',
    legend       = True,
    missing_kwds = {'color': 'lightgrey', 'label': 'No Data'},
    ax           = ax
)

ax.set_title('Mean PFAS Levels by ZIP Code in New Jersey (µg/L)',
             fontsize=16, fontweight='bold', pad=20)
ax.set_axis_off()

plt.tight_layout()
plt.savefig('output/nj_pfas_map_mean.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Max PFAS concentration by ZIP (µg/L)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 14))

map_df.plot(
    column       = 'max_pfas',
    cmap         = 'OrRd',
    linewidth    = 0.5,
    edgecolor    = 'black',
    legend       = True,
    missing_kwds = {'color': 'lightgrey', 'label': 'No Data'},
    ax           = ax
)

ax.set_title('Max PFAS Levels by ZIP Code in New Jersey (µg/L)',
             fontsize=16, fontweight='bold', pad=20)
ax.set_axis_off()

plt.tight_layout()
plt.savefig('output/nj_pfas_map_max.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Max binary map ZIP codes exceeding EPA MCL (0.004 µg/L)

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 14))

cmap_binary = ListedColormap(['darkseagreen', 'indianred'])

map_df.plot(
    column       = 'exceeds_mcl_max',
    cmap         = cmap_binary,
    linewidth    = 0.5,
    edgecolor    = 'black',
    legend       = False,
    missing_kwds = {'color': 'lightgrey'},
    ax           = ax
)

legend_elements = [
    Patch(facecolor='indianred', edgecolor='black', label='Exceeds EPA MCL (> 0.004 µg/L)'),
    Patch(facecolor='darkseagreen', edgecolor='black', label='Below EPA MCL'),
    Patch(facecolor='lightgrey', edgecolor='black', label='No Data'),
]
ax.legend(handles=legend_elements, loc='lower left', fontsize=11)

ax.set_title('ZIP Codes Exceeding EPA PFAS Limit (0.004 µg/L) in New Jersey',
             fontsize=15, fontweight='bold', pad=20)
ax.set_axis_off()

plt.tight_layout()
plt.savefig('output/nj_pfas_exceeds_mcl.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## PFAS contamination vs race (side by side)

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 14))

# Left — mean PFAS
map_df.plot(
    column       = 'mean_pfas',
    cmap         = 'OrRd',
    linewidth    = 0.5,
    edgecolor    = 'grey',
    legend       = True,
    missing_kwds = {'color': 'lightgrey'},
    ax           = axes[0]
)
legend = axes[0].get_legend()
if legend is not None:
    legend.set_title('PFAS (µg/L)', prop={'size': 10})
axes[0].set_title('Mean PFAS Concentration by ZIP (µg/L)', fontsize=14, fontweight='bold')
axes[0].set_axis_off()

# Right — % POC
map_df.plot(
    column       = 'pct_poc',
    cmap         = 'Blues',
    linewidth    = 0.5,
    edgecolor    = 'grey',
    legend       = True,
    missing_kwds = {'color': 'lightgrey'},
    ax           = axes[1]
)
legend = axes[1].get_legend()
if legend is not None:
    legend.set_title('% POC', prop={'size': 10})
axes[1].set_title('% People of Color by ZIP', fontsize=14, fontweight='bold')
axes[1].set_axis_off()

plt.suptitle('PFAS Contamination vs Race in New Jersey',
             fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('output/nj_pfas_vs_race_map.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## PFAS vs Income

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 14))

# Left — mean PFAS
map_df.plot(
    column       = 'mean_pfas',
    cmap         = 'OrRd',
    linewidth    = 0.5,
    edgecolor    = 'grey',
    legend       = True,
    missing_kwds = {'color': 'lightgrey'},
    ax           = axes[0]
)
legend = axes[0].get_legend()
if legend is not None:
    legend.set_title('PFAS (µg/L)', prop={'size': 10})
axes[0].set_title('Mean PFAS Concentration by ZIP (µg/L)', fontsize=14, fontweight='bold')
axes[0].set_axis_off()

# Right — mean household income
map_df.plot(
    column       = 'hh_mean_income',
    cmap         = 'Greens',
    linewidth    = 0.5,
    edgecolor    = 'grey',
    legend       = True,
    missing_kwds = {'color': 'lightgrey'},
    ax           = axes[1]
)
legend = axes[1].get_legend()
if legend is not None:
    legend.set_title('Income', prop={'size': 10})
axes[1].set_title('Household Mean Income by ZIP', fontsize=14, fontweight='bold')
axes[1].set_axis_off()

plt.suptitle('PFAS Contamination vs Household Income in New Jersey',
             fontsize=16, fontweight='bold', y=1.02)
plt.tight_layout()
plt.savefig('output/nj_pfas_vs_income_map.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Pearsons Correlation Test (race and PFAS)

# %%
from scipy import stats
import pandas as pd

# Drop rows where either value is missing
pt_df = map_df[['mean_pfas', 'max_pfas', 'pct_poc', 'pct_black', 'pct_hispanic']].dropna()

pt_df['mean_pfas']   = pd.to_numeric(pt_df['mean_pfas'], errors='coerce')
pt_df['max_pfas']    = pd.to_numeric(pt_df['max_pfas'], errors='coerce')
pt_df['pct_poc']     = pd.to_numeric(pt_df['pct_poc'], errors='coerce')
pt_df['pct_black']   = pd.to_numeric(pt_df['pct_black'], errors='coerce')
pt_df['pct_hispanic']= pd.to_numeric(pt_df['pct_hispanic'], errors='coerce')
pt_df = pt_df.dropna()

# %% [markdown]
# PFAS and poc

# %%
corr, pvalue = stats.pearsonr(pt_df['mean_pfas'], pt_df['pct_poc'])

print(f'Pearson r:   {corr:.3f}')
print(f'P-value:     {pvalue:.4f}')
# Out:
# Pearson r:   0.123
# P-value:     0.0073

# %% [markdown]
# PFAS and Black

# %%
corr, pvalue = stats.pearsonr(pt_df['mean_pfas'], pt_df['pct_black'])

print(f'Pearson r:   {corr:.3f}')
print(f'P-value:     {pvalue:.4f}')
# Out:
# Pearson r:   -0.097
# P-value:     0.0351

# %%
corr, pvalue = stats.pearsonr(pt_df['mean_pfas'], pt_df['pct_hispanic'])

print(f'Pearson r:   {corr:.3f}')
print(f'P-value:     {pvalue:.4f}')
# Out:
# Pearson r:   0.245
# P-value:     0.0000

# %% [markdown]
# ## Pearsons Correlation Test (income and PFAS)

# %%
from scipy import stats
import pandas as pd

# Drop rows where either value is missing
pt_df = map_df[['mean_pfas', 'hh_mean_income']].dropna()

pt_df['mean_pfas']   = pd.to_numeric(pt_df['mean_pfas'], errors='coerce')
pt_df['hh_mean_income'] = pd.to_numeric(pt_df['hh_mean_income'], errors='coerce')
pt_df = pt_df.dropna()

corr, pvalue = stats.pearsonr(pt_df['mean_pfas'], pt_df['hh_mean_income'])

print(f'Pearson r:   {corr:.3f}')
print(f'P-value:     {pvalue:.4f}')
# Out:
# Pearson r:   0.123
# P-value:     0.0076

# %% [markdown]
# ## Visualizing Pearson Corelation Test

# %%
# Rebuild pt_df with pct_poc for this plot
pt_df = map_df[['mean_pfas', 'pct_poc']].copy()
pt_df['mean_pfas'] = pd.to_numeric(pt_df['mean_pfas'], errors='coerce')
pt_df['pct_poc']   = pd.to_numeric(pt_df['pct_poc'], errors='coerce')
pt_df = pt_df.dropna()

corr, pvalue = stats.pearsonr(pt_df['mean_pfas'], pt_df['pct_poc'])

# --- Plot ---
fig, ax = plt.subplots(figsize=(10, 7))

ax.scatter(
    pt_df['mean_pfas'],
    pt_df['pct_poc'],
    color     = 'indianred',
    alpha     = 0.5,
    edgecolor = 'white',
    linewidth = 0.5,
    s         = 60,
    label     = 'ZIP Code'
)

# Regression line
m, b = np.polyfit(pt_df['mean_pfas'], pt_df['pct_poc'], 1)
x_line = np.linspace(pt_df['mean_pfas'].min(), pt_df['mean_pfas'].max(), 100)
ax.plot(x_line, m * x_line + b,
        color     = 'black',
        linewidth = 2,
        label     = 'Regression Line')

# EPA MCL vertical line
ax.axvline(x=0.004, color='darkred', linestyle='--', linewidth=1.5, label='EPA MCL (0.004 µg/L)')

ax.set_xlabel('Mean PFAS Concentration (µg/L)', fontsize=13)
ax.set_ylabel('% People of Color', fontsize=13)
ax.set_title('PFAS Concentration vs. % People of Color\nby ZIP Code in New Jersey',
             fontsize=15, fontweight='bold', pad=15)

ax.text(
    0.97, 0.05,
    f'r = {corr:.3f}\np = {pvalue:.4f}',
    transform            = ax.transAxes,
    fontsize             = 12,
    verticalalignment    = 'bottom',
    horizontalalignment  = 'right',
    bbox                 = dict(boxstyle='round', facecolor='white', alpha=0.8)
)

ax.legend(fontsize=11)
plt.tight_layout()

os.makedirs('output', exist_ok=True)
plt.savefig('output/pfas_vs_poc_scatter.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## T-Test

# %%
tt_df = map_df[['exceeds_mcl_mean', 'pct_poc']].dropna()
tt_df['pct_poc'] = pd.to_numeric(tt_df['pct_poc'], errors='coerce')
tt_df = tt_df.dropna()

exceeds     = tt_df[tt_df['exceeds_mcl_mean'] == True]['pct_poc']
not_exceeds = tt_df[tt_df['exceeds_mcl_mean'] == False]['pct_poc']

t_stat, pvalue = stats.ttest_ind(exceeds, not_exceeds)

print(f'Avg % POC in ZIPs EXCEEDING MCL:     {exceeds.mean():.1f}%')
print(f'Avg % POC in ZIPs NOT exceeding MCL: {not_exceeds.mean():.1f}%')
print(f'Difference:                          {exceeds.mean() - not_exceeds.mean():.1f}%')
print(f'T-statistic: {t_stat:.3f}')
print(f'P-value:     {pvalue:.4f}')
# Out:
# Avg % POC in ZIPs EXCEEDING MCL:     15.2%
# Avg % POC in ZIPs NOT exceeding MCL: 25.5%
# Difference:                          -10.3%
# T-statistic: -0.464
# P-value:     0.6427

# %% [markdown]
# ## PFAS vs Income Brackets (Pearson Correlations)

# %%
# Pearson correlation between mean PFAS and each household income bracket
# Brackets are % of households in that income range

income_brackets = {
    'Less than $10k'    : 'hh_less_than_10k',
    '$10k–$15k'         : 'hh_10k_to_15k',
    '$15k–$25k'         : 'hh_15k_to_25k',
    '$25k–$35k'         : 'hh_25k_to_35k',
    '$35k–$50k'         : 'hh_35k_to_50k',
    '$50k–$75k'         : 'hh_50k_to_75k',
    '$75k–$100k'        : 'hh_75k_to_100k',
    '$100k–$150k'       : 'hh_100k_to_150k',
    '$150k–$200k'       : 'hh_150k_to_200k',
    '$200k or more'     : 'hh_200k_or_more',
}

print(f"{'Income Bracket':<22} {'Pearson r':>10} {'P-value':>10} {'Sig':>6}")
print("-" * 52)

bracket_results = []
for label, col in income_brackets.items():
    tmp = map_df[['mean_pfas', col]].copy()
    tmp['mean_pfas'] = pd.to_numeric(tmp['mean_pfas'], errors='coerce')
    tmp[col]         = pd.to_numeric(tmp[col], errors='coerce')
    tmp = tmp.dropna()
    corr, pvalue = stats.pearsonr(tmp['mean_pfas'], tmp[col])
    sig = '***' if pvalue < 0.001 else '**' if pvalue < 0.01 else '*' if pvalue < 0.05 else ''
    bracket_results.append({'label': label, 'col': col, 'r': corr, 'p': pvalue})
    print(f"{label:<22} {corr:>10.3f} {pvalue:>10.4f} {sig:>6}")
# Out:
# Income Bracket          Pearson r    P-value    Sig
# ----------------------------------------------------
# Less than $10k             -0.017     0.7073
# $10k–$15k                   0.011     0.8068
# $15k–$25k                   0.046     0.3155
# $25k–$35k                  -0.060     0.1974
# $35k–$50k                  -0.035     0.4431
# $50k–$75k                  -0.038     0.4102
# $75k–$100k                 -0.178     0.0001    ***
# $100k–$150k                -0.174     0.0002    ***
# $150k–$200k                -0.041     0.3739
# $200k or more               0.149     0.0012     **

# %% [markdown]
# ## Multiple Regression: Race + Income Predicting Mean PFAS

# %%
import statsmodels.api as sm

# Predictors: race + income
predictors = ['pct_poc', 'pct_black', 'pct_hispanic', 'hh_median_income']

reg_df = map_df[['mean_pfas'] + predictors].copy()
for col in reg_df.columns:
    reg_df[col] = pd.to_numeric(reg_df[col], errors='coerce')
reg_df = reg_df.dropna()

X = sm.add_constant(reg_df[predictors])
y = reg_df['mean_pfas']

model = sm.OLS(y, X).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:              mean_pfas   R-squared:                       0.175
# Model:                            OLS   Adj. R-squared:                  0.168
# Method:                 Least Squares   F-statistic:                     23.99
# Date:                Thu, 04 Jun 2026   Prob (F-statistic):           5.20e-18
# Time:                        13:01:50   Log-Likelihood:                 2773.7
# No. Observations:                 456   AIC:                            -5537.
# Df Residuals:                     451   BIC:                            -5517.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -0.0002      0.000     -1.503      0.133      -0.000    5.57e-05
# ...

# %% [markdown]
# ## Box Plots: Mean PFAS by Household Income Quartile

# %%
box_df = map_df[['mean_pfas', 'hh_median_income']].copy()
box_df['mean_pfas']        = pd.to_numeric(box_df['mean_pfas'], errors='coerce')
box_df['hh_median_income'] = pd.to_numeric(box_df['hh_median_income'], errors='coerce')
box_df = box_df.dropna()

# Split into income quartiles
box_df['income_quartile'] = pd.qcut(
    box_df['hh_median_income'],
    q     = 4,
    labels= ['Q1\n(Lowest)', 'Q2', 'Q3', 'Q4\n(Highest)']
)

# Build list of PFAS values per quartile
groups = [box_df[box_df['income_quartile'] == q]['mean_pfas'].values
          for q in ['Q1\n(Lowest)', 'Q2', 'Q3', 'Q4\n(Highest)']]
quartile_ranges = (
    box_df.groupby('income_quartile', observed=True)['hh_median_income']
    .agg(['min', 'max'])
    .apply(lambda r: f"${r['min']/1000:.0f}k–${r['max']/1000:.0f}k", axis=1)
    .to_dict()
)
tick_labels = [f"{q}\n{quartile_ranges[q]}" for q in ['Q1\n(Lowest)', 'Q2', 'Q3', 'Q4\n(Highest)']]

fig, ax = plt.subplots(figsize=(10, 6))
bp = ax.boxplot(groups, tick_labels=tick_labels, patch_artist=True,
                medianprops={'color': 'black', 'linewidth': 2})

colors = ['#c6dbef', '#6baed6', '#2171b5', '#08306b']
for patch, color in zip(bp['boxes'], colors):
    patch.set_facecolor(color)
    patch.set_alpha(0.8)

ax.axhline(y=0.004, color='darkred', linestyle='--', linewidth=1.5, label='EPA MCL (0.004 µg/L)')
ax.set_xlabel('Household Income Quartile (Median Income)', fontsize=12)
ax.set_ylabel('Mean PFAS Concentration (µg/L)', fontsize=12)
ax.set_title('Mean PFAS Levels by Household Income Quartile\nin New Jersey ZIP Codes',
             fontsize=14, fontweight='bold')
ax.legend(fontsize=11)

plt.tight_layout()
plt.savefig('output/pfas_by_income_quartile_boxplot.png', dpi=300, bbox_inches='tight')
plt.show()
